# %%
import pandas as pd
import numpy as np
df = pd.read_csv("Employee_Database.csv")

# %%
df
# Out:
#              Name  Age  Gender   JobRole  Experience  WorkHoursPerWeek  \
# 0      Max Ivanov   32    Male   Analyst           3                60
# 1        Max Wang   40  Female  Engineer           9                47
# 2     Nina Petrov   33  Female  Engineer           2                44
# 3     John Ivanov   35  Female   Manager           6                44
# 4       John Wang   59    Male     Sales           8                38
# ...           ...  ...     ...       ...         ...               ...
# 1995    Leo Brown   41  Female   Manager           4                63
# 1996   Alex Brown   23  Female        HR           2                39
# 1997    Nina Wang   31  Female        HR          10                39
# 1998     Kate Lee   25    Male        HR           0                40
# 1999  Lily Petrov   49  Female  Engineer          13                65
#
#       RemoteRatio  SatisfactionLevel  StressLevel  Burnout
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               2000 non-null   object
#  1   Age                2000 non-null   int64
#  2   Gender             2000 non-null   object
#  3   JobRole            2000 non-null   object
#  4   Experience         2000 non-null   int64
#  5   WorkHoursPerWeek   2000 non-null   int64
#  6   RemoteRatio        2000 non-null   int64
#  7   SatisfactionLevel  2000 non-null   float64
#  8   StressLevel        2000 non-null   int64
#  9   Burnout            2000 non-null   int64
# dtypes: float64(1), int64(6), object(3)
# memory usage: 156.4+ KB

# %%
df.describe()
# Out:
#                Age   Experience  WorkHoursPerWeek  RemoteRatio  \
# count  2000.000000  2000.000000       2000.000000  2000.000000
# mean     40.694500    10.074500         49.588000    49.973000
# std      11.286756     9.148267         11.832424    29.151298
# min      22.000000     0.000000         30.000000     0.000000
# 25%      31.000000     3.000000         39.000000    24.000000
# 50%      41.000000     7.000000         49.000000    49.000000
# 75%      50.000000    15.000000         60.000000    75.000000
# max      60.000000    39.000000         70.000000   100.000000
#
#        SatisfactionLevel  StressLevel      Burnout
# count        2000.000000   2000.00000  2000.000000
# mean            2.995230      5.43200     0.064500
# std             1.155431      2.88089     0.245703
# min             1.000000      1.00000     0.000000
# 25%             2.000000      3.00000     0.000000
# 50%             3.025000      5.00000     0.000000
# ...

# %%
df.columns   #number of columns in this file
# Out:
# Index(['Name', 'Age', 'Gender', 'JobRole', 'Experience', 'WorkHoursPerWeek',
#        'RemoteRatio', 'SatisfactionLevel', 'StressLevel', 'Burnout'],
#       dtype='object')

# %%
df.Burnout
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1995    0
# 1996    0
# 1997    0
# 1998    0
# 1999    0
# Name: Burnout, Length: 2000, dtype: int64

# %%
df['Burnout'].unique()
# Out:
# array([0, 1])

# %%
df['Burnout'].nunique()
# Out:
# 2

# %%
df[df['Age'] >= 50]
# Out:
#              Name  Age  Gender  JobRole  Experience  WorkHoursPerWeek  \
# 4       John Wang   59    Male    Sales           8                38
# 11       Max Wang   55    Male       HR          11                59
# 12      Nina Chen   55    Male  Manager          11                34
# 13      Lily Wang   53  Female    Sales          26                57
# 17     Max Ivanov   60  Female    Sales          21                52
# ...           ...  ...     ...      ...         ...               ...
# 1965  Leo Johnson   56    Male  Analyst          11                52
# 1968  John Garcia   53    Male       HR          26                43
# 1973     Alex Lee   52    Male       HR          10                49
# 1982     John Lee   54  Female  Manager          30                57
# 1985     Dina Kim   50    Male       HR          27                57
#
#       RemoteRatio  SatisfactionLevel  StressLevel  Burnout
# 4              46               4.41            1        0
# ...

# %%
df[df['Experience'] >= 10].min()
#df[df['Experience'] >= 23].max()
# Out:
# Name                 Alex Brown
# Age                          31
# Gender                   Female
# JobRole                 Analyst
# Experience                   10
# WorkHoursPerWeek             30
# RemoteRatio                   0
# SatisfactionLevel          1.01
# StressLevel                   1
# Burnout                       0
# dtype: object

# %%
df[df['SatisfactionLevel'] == 1.80]
# Out:
#              Name  Age  Gender  JobRole  Experience  WorkHoursPerWeek  \
# 451   Kate Petrov   22  Female  Manager           1                47
# 1265   Max Ivanov   49  Female    Sales          24                68
# 1482    Lily Chen   54    Male    Sales          30                61
#
#       RemoteRatio  SatisfactionLevel  StressLevel  Burnout
# 451             5                1.8            5        0
# 1265           98                1.8            4        0
# 1482           37                1.8            8        1

# %%
df[(df['SatisfactionLevel'] == "hr-Burnout") & (df["SatisfactionLevel"] >= 4.67)]
# Out:
# Empty DataFrame
# Columns: [Name, Age, Gender, JobRole, Experience, WorkHoursPerWeek, RemoteRatio, SatisfactionLevel, StressLevel, Burnout]
# Index: []

# %%
our_array = np.random.randn(200,5)
our_array
# Out:
# array([[ 1.84561342e-01,  5.41232651e-04,  1.05560168e+00,
#          1.20176100e+00, -1.58333914e-01],
#        [ 3.51137112e-01, -4.95574410e-02,  8.24965237e-01,
#         -1.08750868e+00, -5.04493375e-01],
#        [-1.22108200e+00,  2.10630015e-01, -7.57332258e-01,
#          1.13307018e+00, -1.17528559e+00],
#        [-4.36366785e-01, -7.00764845e-01,  8.17310271e-01,
#         -1.95859837e+00,  9.81397079e-01],
#        [ 2.03129046e-01,  2.33531793e+00, -2.44493885e-01,
#          6.74659992e-01,  7.42883470e-01],
#        [-4.91622759e-01, -3.18772111e-01,  1.88935544e+00,
#          1.05181504e+00,  1.28452651e+00],
#        [ 3.64322103e-01,  7.42295210e-01,  1.24831756e+00,
#          2.84241123e-01,  1.18805443e+00],
#        [ 3.83419001e-02, -9.96004979e-01,  2.94905387e-01,
#          3.25831625e-01, -7.85047011e-02],
#        [-6.80208379e-01,  3.24107673e-02,  1.70138432e-01,
#         -2.73794208e+00, -8.21751951e-01],
# ...

# %%
df.head()
# Out:
#           Name  Age  Gender   JobRole  Experience  WorkHoursPerWeek  \
# 0   Max Ivanov   32    Male   Analyst           3                60
# 1     Max Wang   40  Female  Engineer           9                47
# 2  Nina Petrov   33  Female  Engineer           2                44
# 3  John Ivanov   35  Female   Manager           6                44
# 4    John Wang   59    Male     Sales           8                38
#
#    RemoteRatio  SatisfactionLevel  StressLevel  Burnout
# 0           21               4.40            1        0
# 1           67               2.09            2        0
# 2           20               2.58            3        0
# 3           70               3.23            8        0
# 4           46               4.41            1        0

# %%
df.tail()
# Out:
#              Name  Age  Gender   JobRole  Experience  WorkHoursPerWeek  \
# 1995    Leo Brown   41  Female   Manager           4                63
# 1996   Alex Brown   23  Female        HR           2                39
# 1997    Nina Wang   31  Female        HR          10                39
# 1998     Kate Lee   25    Male        HR           0                40
# 1999  Lily Petrov   49  Female  Engineer          13                65
#
#       RemoteRatio  SatisfactionLevel  StressLevel  Burnout
# 1995           17               3.40            4        0
# 1996           20               4.67            9        0
# 1997            4               4.10            4        0
# 1998           57               2.11            4        0
# 1999           22               4.36            8        0

# %% [markdown]
# Summary in this file:-
#                       this file is a
